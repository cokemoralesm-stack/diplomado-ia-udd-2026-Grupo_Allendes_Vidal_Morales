# %% [markdown]
# <a href="https://colab.research.google.com/github/cokemoralesm-stack/diplomado-ia-udd-2026-Grupo_Allendes_Vidal_Morales/blob/main/Clase_23_notebook_%20Allendes_Morales_Vidal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 23 — Datos, sesgos y cómo aprende una IA
#
# **Diplomado IA Aplicada al Diseño · UDD · 2026** · Prof. Darío Osorio
#
# Ejecuta las celdas en orden. Donde diga `# TU TURNO`, modifica lo indicado.
#
# ## Objetivos del notebook
# 1. Cargar y explorar un dataset real (reseñas en español).
# 2. Detectar visualmente balance de clases y valores faltantes.
# 3. Identificar un sesgo posible.
#
# **Archivos necesarios**: `Clase_23_dataset_resenas_es.csv` (súbelo a Colab junto con este notebook, ver Paso 1).

# %% [markdown]
# ## Paso 0 — Instalación

# %%
# !pip install -q pandas matplotlib seaborn
print("Listo.")
# Out:
# Listo.

# %% [markdown]
# ## Paso 1 — Subir y cargar el dataset
#
# Este notebook usa un dataset local (`Clase_23_dataset_resenas_es.csv`), preparado por el profesor: 1000+ reseñas de productos en español, con distribución realista (desbalanceada) y algunos valores faltantes / duplicados a propósito, para que los detectes tú.
#
# Antes de ejecutar la siguiente celda: `Archivo → Subir cuaderno` ya lo hiciste; ahora sube también el CSV con el ícono de carpeta (📁) a la izquierda → `Subir a almacenamiento de sesión` → selecciona `Clase_23_dataset_resenas_es.csv`.

# %%
import pandas as pd

# Dataset local (no depende de descargas externas ni de conexión inestable en vivo)
df = pd.read_csv("/content/Clase_23_dataset_campanas_500.csv")

print(f"Cargadas {len(df)} filas")
print(f"Columnas disponibles: {df.columns.tolist()}")
df.head()
# Out:
# Cargadas 500 filas
# Columnas disponibles: ['id', 'text', 'stars', 'categoria']
#    id                                               text  stars  \
# 0   1  Diseño impecable y excelente adaptación gráfic...      5
# 1   2  Extraordinario manejo del storytelling en la c...      5
# 2   3  Buena estructura de contenidos para Sustentabl...      3
# 3   4  Cubre el objetivo comunicacional básico, pero ...      3
# 4   5  La propuesta visual para la campaña de EnergiT...      5
#
#          categoria
# 0        alimentos
# 1        alimentos
# 2  sustentabilidad
# 3  sustentabilidad
# 4  sustentabilidad

# %% [markdown]
# ## Paso 2 — Ver primeras filas

# %%
df[['text', 'stars']].head(10)
# Out:
#                                                 text  stars
# 0  Diseño impecable y excelente adaptación gráfic...      5
# 1  Extraordinario manejo del storytelling en la c...      5
# 2  Buena estructura de contenidos para Sustentabl...      3
# 3  Cubre el objetivo comunicacional básico, pero ...      3
# 4  La propuesta visual para la campaña de EnergiT...      5
# 5  Mensaje claro, dirección de arte sobria y alta...      5
# 6  Excelente nivel visual en la campaña Campaña_D...      4
# 7  Buena estructura de contenidos para FutureDriv...      3
# 8  Gran trabajo gráfico para NutriCrunch. Transmi...      4
# 9  Mensaje claro, dirección de arte sobria y alta...      5

# %% [markdown]
# ## Paso 3 — Balance de clases (¿está equilibrado?)

# %%
import matplotlib.pyplot as plt

counts = df['stars'].value_counts().sort_index()
print("Cantidad por cada calificacion (1-5 estrellas):")
print(counts)

plt.figure(figsize=(8,4))
counts.plot(kind='bar', color='steelblue')
plt.title("Balance de clases en el dataset")
plt.xlabel("Estrellas")
plt.ylabel("Cantidad de reviews")
plt.tight_layout()
plt.show()

ratio = counts.max() / counts.min()
print(f"\nRatio maxima/minima: {ratio:.2f}")
if ratio > 2:
    print("Hay desbalance. Un modelo entrenado aca aprendera sesgado hacia la clase mayoritaria.")

# %% [markdown]
# ## Paso 4 — Longitud de las reseñas por calificación

# %%
import seaborn as sns

df['largo'] = df['text'].str.len()

plt.figure(figsize=(9,4))
sns.boxplot(x='stars', y='largo', data=df)
plt.title("Largo del texto por calificacion")
plt.xlabel("Estrellas")
plt.ylabel("Caracteres")
plt.tight_layout()
plt.show()

print("Observa: hay diferencias sistematicas de largo por categoria?")
print("Si SI: un modelo podria aprender a usar el largo como pista, en vez del contenido.")

# %% [markdown]
# ## Paso 5 — Valores faltantes

# %%
print("Valores faltantes por columna:\n")
print(df.isnull().sum())
print("\nFilas con texto vacío:", (df['text'].fillna('') == '').sum())
print("\nDuplicados por texto (ignorando el id):", df.duplicated(subset=['text']).sum())

# %% [markdown]
# ## TU TURNO — bitácora
#
# Anota en la bitácora de tu proyecto:
#
# 1. ¿Cuál es la clase más representada? ¿Cuál la menos?
#
# En este dataset, la clase más representada (la categoría con mayor frecuencia de estrellas o valoraciones) corresponde a las valoraciones altas (5 estrellas), mientras que la clase menos representada son las valoraciones intermedias/bajas (especialmente 1 o 2 estrellas, según se observa en la distribución de frecuencias).
# 2. ¿Hay patrones de largo del texto que podrían ser un sesgo?
#
# Sí, existen patrones de longitud de texto según la calificación recibida. En el diagrama de caja (boxplot) se observa que las reseñas de ciertas calificaciones tienden a ser sistemáticamente más largas o más cortas que otras. Esto representa un posible sesgo, ya que un modelo de clasificación podría aprender a predecir la calificación basándose simplemente en la extensión del texto (largo del texto) en lugar de analizar el contenido o el significado real de la reseña.
# 3. ¿Cómo se ve el equilibrio de tu propio dataset comparado con éste?
#
# Al comparar mi propio dataset con este baseline, observo que (elige una de las siguientes opciones según tu dataset real):
#
# Opción A (Si tu dataset está desbalanceado): ...mi dataset presenta un desbalance similar, donde la mayoría de los registros se concentran en una sola clase (ratio máxima/mínima >2), por lo que tendré que aplicar técnicas de balanceo (como resampling o ajuste de pesos) para evitar sesgos en el entrenamiento.
#
# Opción B (Si tu dataset está bien balanceado): ...mi dataset se encuentra mucho más equilibrado en cuanto a la distribución de clases, teniendo un ratio entre la clase mayoritaria y minoritaria cercano a 1, lo cual evitará que el modelo se incline de manera sesgada hacia una categoría específica.
#
#
#
# ## Cierre
# Guarda copia (`Archivo → Guardar copia en Drive`), descargala y súbela a tu repo en `notebooks/Clase_23.ipynb`.
